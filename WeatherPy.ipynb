# %%
import random 
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime

# %%
# Create random latitudes and longitudes combinations that is x and y points 
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Create a practice set of random latitude and longitude combinations.x and y has 1500 points each 
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)
coordinates

# %%
#combine matching coordinates for all 1500 pints ,lat_lngs is a variable that holds zip (lat ,lngs) x= lats y =lngs
# Add the latitudes and longitudes to a list.this is also unzip the tuple and make it into a list
coordinates = list(lat_lngs)
coordinates
# Out:
# [(-17.512241139123603, 17.241621499986877),
#  (-43.39053081247931, 67.10367593855705),
#  (-40.20218455928536, -44.44402635126829),
#  (38.34668560394081, 107.69191321378304),
#  (76.47553640919011, 128.33474515625886),
#  (78.30886245390388, 130.92345152421393),
#  (35.59271424891797, -77.37229393485042),
#  (-15.903566559238186, -86.8151766830386),
#  (-37.607338164494195, 10.63611585881975),
#  (-87.85575026113771, 53.847631581557295),
#  (78.53025654835861, 3.0218165660274963),
#  (-19.19759772085635, -125.30888048337131),
#  (-50.808391312261094, 177.74080728692581),
#  (-17.721129495514575, 45.90065482721894),
#  (23.98445228950736, -67.59775749682487),
#  (-28.765995751440137, 7.809972845469815),
#  (42.307542876514134, -52.34878247814598),
#  (-60.324609061714895, 175.38056998658607),
#  (41.113867176517914, -48.97887848813983),
#  (19.890191791312773, -57.430734760807695),
#  (81.59715932070756, -149.50989311595512),
#  (-30.900985167696632, -92.97805638546846),
# ...

# %%
# Use the tuple() function to display the latitude and longitude combinations.calling an index 0,1 in the zip(x,y)
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# -17.512241139123603 17.241621499986877
# -43.39053081247931 67.10367593855705
# -40.20218455928536 -44.44402635126829
# 38.34668560394081 107.69191321378304
# 76.47553640919011 128.33474515625886
# 78.30886245390388 130.92345152421393
# 35.59271424891797 -77.37229393485042
# -15.903566559238186 -86.8151766830386
# -37.607338164494195 10.63611585881975
# -87.85575026113771 53.847631581557295
# 78.53025654835861 3.0218165660274963
# -19.19759772085635 -125.30888048337131
# -50.808391312261094 177.74080728692581
# -17.721129495514575 45.90065482721894
# 23.98445228950736 -67.59775749682487
# -28.765995751440137 7.809972845469815
# 42.307542876514134 -52.34878247814598
# -60.324609061714895 175.38056998658607
# 41.113867176517914 -48.97887848813983
# 19.890191791312773 -57.430734760807695
# 81.59715932070756 -149.50989311595512
# -30.900985167696632 -92.97805638546846
# 61.95259633369028 21.101869380844448
# -53.65364890388488 -109.46045526200184
# -67.25647377637453 42.97596666212195
# ...

# %%
#Python's citipy module.
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# eenhana na
# saint-philippe re
# chuy uy
# yinchuan cn
# tiksi ru
# tiksi ru
# greenville us
# hualmay pe
# cape town za
# port alfred za
# barentsburg sj
# rikitea pf
# dunedin nz
# fenoarivo mg
# cockburn town tc
# luderitz na
# torbay ca
# kaitangata nz
# torbay ca
# codrington ag
# barrow us
# lebu cl
# kristiinankaupunki fi
# castro cl
# port alfred za
# illoqqortoormiut gl
# nome us
# isangel vu
# opuwo na
# havre-saint-pierre ca
# thompson ca
# bluff nz
# rikitea pf
# vaini to
# illoqqortoormiut gl
# gravdal no
# vao nc
# busselton au
# sao joao da barra br
# prince rupert ca
# mataura pf
# rikitea pf
# punta arenas cl
# karaul ru
# shenjiamen cn
# riyadh sa
# cumana ve
# kapaa us
# cidreira br
# new norfolk au
# acapulco mx
# punta arenas cl
# taylor us
# monrovia lr
# yeniseysk ru
# putla mx
# taolanaro mg
# cape town za
# mys shmidta ru
# port alfred za
# ilulissat gl
# micheweni tz
# yadrin ru
# punta arenas cl
# saldanha za
# port elizabeth za
# kavaratti in
# talnakh ru
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination. coordinates[] is a list as well 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 597

# %%
#cities list got 632 cities 
cities
# Out:
# ['eenhana',
#  'saint-philippe',
#  'chuy',
#  'yinchuan',
#  'tiksi',
#  'greenville',
#  'hualmay',
#  'cape town',
#  'port alfred',
#  'barentsburg',
#  'rikitea',
#  'dunedin',
#  'fenoarivo',
#  'cockburn town',
#  'luderitz',
#  'torbay',
#  'kaitangata',
#  'codrington',
#  'barrow',
#  'lebu',
#  'kristiinankaupunki',
#  'castro',
#  'illoqqortoormiut',
#  'nome',
#  'isangel',
#  'opuwo',
#  'havre-saint-pierre',
#  'thompson',
#  'bluff',
#  'vaini',
#  'gravdal',
#  'vao',
#  'busselton',
#  'sao joao da barra',
#  'prince rupert',
#  'mataura',
#  'punta arenas',
#  'karaul',
#  'shenjiamen',
#  'riyadh',
#  'cumana',
#  'kapaa',
#  'cidreira',
#  'new norfolk',
#  'acapulco',
#  'taylor',
#  'monrovia',
#  'yeniseysk',
#  'putla',
#  'taolanaro',
#  'mys shmidta',
#  'ilulissat',
#  'micheweni',
#  'yadrin',
#  'saldanha',
#  'port elizabeth',
#  'kavaratti',
#  'talnakh',
#  'norman wells',
#  'lieksa',
#  'wattegama',
#  'westport',
#  'anadyr',
#  'lloydminster',
# ...

# %%
#url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#add cities in to the city_data_list[]
city_data_list = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# cities = ["Mumbai"]
for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
        
    try:
        # Parse the JSON and retrieve data.
        #request.get next line will exhaust your apikey call so only use when you need 
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data_list.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})


    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb4f89038070a38eeb93e355c7ccc9a3&q=Mumbai

# %%
#{"coord":{"lon":72.8479,"lat":19.0144},"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50n"}],"base":"stations","main":{"temp":80.58,"feels_like":85.15,"temp_min":80.58,"temp_max":80.58,"pressure":1011,"humidity":78},"visibility":2500,"wind":{"speed":4.61,"deg":350},"clouds":{"all":29},"dt":1634857951,"sys":{"type":1,"id":9052,"country":"IN","sunrise":1634864687,"sunset":1634906465},"timezone":19800,"id":1275339,"name":"Mumbai","cod":200}

# %%
city_data_list
# Out:
# [{'City': 'Eenhana',
#   'Lat': -17.4667,
#   'Lng': 16.3333,
#   'Max Temp': 90.32,
#   'Humidity': 13,
#   'Cloudiness': 30,
#   'Wind Speed': 10.58,
#   'Country': 'NA',
#   'Date': '2021-10-21 15:38:35'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 74.79,
#   'Humidity': 77,
#   'Cloudiness': 50,
#   'Wind Speed': 7.61,
#   'Country': 'RE',
#   'Date': '2021-10-21 15:35:42'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 68.68,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Country': 'UY',
#   'Date': '2021-10-21 15:38:35'},
#  {'City': 'Yinchuan',
#   'Lat': 38.4681,
#   'Lng': 106.2731,
#   'Max Temp': 48.67,
#   'Humidity': 25,
#   'Cloudiness': 42,
#   'Wind Speed': 3.22,
#   'Country': 'CN',
#   'Date': '2021-10-21 15:38:35'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 14.43,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
# ...

# %%
cities_data_df= pd.DataFrame(city_data_list)
cities_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Eenhana -17.4667   16.3333     90.32        13          30
# 1  Saint-Philippe -21.3585   55.7679     74.79        77          50
# 2            Chuy -33.6971  -53.4616     68.68        48           0
# 3        Yinchuan  38.4681  106.2731     48.67        25          42
# 4           Tiksi  71.6872  128.8694     14.43        95         100
#
#    Wind Speed Country                 Date
# 0       10.58      NA  2021-10-21 15:38:35
# 1        7.61      RE  2021-10-21 15:35:42
# 2        5.32      UY  2021-10-21 15:38:35
# 3        3.22      CN  2021-10-21 15:38:35
# 4       12.75      RU  2021-10-21 15:38:36

# %%
#Put the dataframe in CSV to avoid api call exhaustion
#cities_data_df.to_csv("cities.csv")

# %%
# read csv
cities_data_df_read_csv=pd.read_csv("cities.csv")

# %%
cities_data_df_read_csv
# Out:
#      Unnamed: 0             City      Lat       Lng  Max Temp  Humidity  \
# 0             0          Eenhana -17.4667   16.3333     90.32        13
# 1             1   Saint-Philippe -21.3585   55.7679     74.79        77
# 2             2             Chuy -33.6971  -53.4616     68.68        48
# 3             3         Yinchuan  38.4681  106.2731     48.67        25
# 4             4            Tiksi  71.6872  128.8694     14.43        95
# ..          ...              ...      ...       ...       ...       ...
# 533         533           Lobito -12.3481   13.5456     77.16        77
# 534         534  Aleksandrov Gay  50.1470   48.5704     48.74        40
# 535         535       Srikakulam  18.3000   83.9000     81.05        80
# 536         536           Tiarei -17.5333 -149.3333     75.22        80
# 537         537             Bara  10.3744   10.7288     92.21        42
#
#      Cloudiness  Wind Speed Country                 Date
# ...

# %%
#  Create the output file (CSV).
# output_data_file = "weather_data/cities.csv"
# # Export the City_Data into a CSV.
# city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
cities_data_df_read_csv.rename(columns= {"Unnamed: 0" : "city-id"}, inplace = True)

# %%
cities_data_df_read_csv.rename(columns= {"" : "city-id"}, inplace = True)

# %%
cities_data_df_read_csv
# Out:
#      city-id             City      Lat       Lng  Max Temp  Humidity  \
# 0          0          Eenhana -17.4667   16.3333     90.32        13
# 1          1   Saint-Philippe -21.3585   55.7679     74.79        77
# 2          2             Chuy -33.6971  -53.4616     68.68        48
# 3          3         Yinchuan  38.4681  106.2731     48.67        25
# 4          4            Tiksi  71.6872  128.8694     14.43        95
# ..       ...              ...      ...       ...       ...       ...
# 533      533           Lobito -12.3481   13.5456     77.16        77
# 534      534  Aleksandrov Gay  50.1470   48.5704     48.74        40
# 535      535       Srikakulam  18.3000   83.9000     81.05        80
# 536      536           Tiarei -17.5333 -149.3333     75.22        80
# 537      537             Bara  10.3744   10.7288     92.21        42
#
#      Cloudiness  Wind Speed Country                 Date
# 0            30       10.58     NaN  2021-10-21 15:38:35
# ...

# %%
cities_data_df_read_csv.describe()
# Out:
#           city-id         Lat         Lng    Max Temp    Humidity  Cloudiness  \
# count  538.000000  538.000000  538.000000  538.000000  538.000000  538.000000
# mean   268.500000   22.050803   18.045524   60.364219   71.117100   60.133829
# std    155.451493   33.997282   90.659983   22.333894   20.299325   37.082634
# min      0.000000  -54.800000 -179.166700  -16.740000    9.000000    0.000000
# 25%    134.250000   -6.287125  -62.236300   41.317500   62.000000   20.000000
# 50%    268.500000   27.851100   22.514650   66.910000   75.000000   75.000000
# 75%    402.750000   50.667575   99.946350   78.040000   87.000000   96.000000
# max    537.000000   78.218600  178.416700  102.130000  100.000000  100.000000
#
#        Wind Speed
# count  538.000000
# mean     7.946691
# std      5.725094
# min      0.000000
# 25%      3.745000
# 50%      6.475000
# 75%     11.092500
# max     33.380000

# %%
lats
# Out:
# 0     -17.4667
# 1     -21.3585
# 2     -33.6971
# 3      38.4681
# 4      71.6872
#         ...
# 533   -12.3481
# 534    50.1470
# 535    18.3000
# 536   -17.5333
# 537    10.3744
# Name: Lat, Length: 538, dtype: float64

# %%
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1634852647.3104613

# %%
today= time.strftime("%x")
today
# Out:
# '10/21/21'

# %%
#mod 6.3.1
# Extract relevant fields from the DataFrame for plotting.
lats = cities_data_df_read_csv["Lat"]
max_temps = cities_data_df_read_csv["Max Temp"]
humidity = cities_data_df_read_csv["Humidity"]
cloudiness = cities_data_df_read_csv["Cloudiness"]
wind_speed = cities_data_df_read_csv["Wind Speed"]

# %%
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.ylim(40,110)
# Save the figure.
plt.savefig("resources/Fig1.png")

# Show plot.
plt.show()

# %%
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. humidity "+ time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("resources/Fig2.png")

# Show plot.
plt.show()

# %%
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. cloudiness (%)"+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("resources/Fig3.png")

# Show plot.
plt.show()

# %%
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. wind_speed "+ time.strftime("%x"))
plt.ylabel("wind_speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("resources/Fig4.png")

# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
# lats 
# max_temps
# humidity 
# cloudiness 
# wind_speed 
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress

# %%
# x=lats
# y=max_temps
# linear_regressor = LinearRegression() 
# linear_regressor

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(lats, max_temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.42x + 69.59
# The p-value is: 0.000

# %%
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Create a scatter plot and plot the regression line.

plt.scatter(lats, max_temps)
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.title('Latitide vs Max Temp regression')
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
#plt.savefig("resources/Fig5.png")
plt.show()

# %%
row = cities_data_df_read_csv.loc[13]
row
# Out:
# city-id                        13
# City                     Luderitz
# Lat                      -26.6481
# Lng                       15.1594
# Max Temp                    59.67
# Humidity                       82
# Cloudiness                     10
# Wind Speed                  14.74
# Country                       NaN
# Date          2021-10-21 15:34:04
# Name: 13, dtype: object

# %%
#filter df by row value 
cities_data_df_read_csv["Lat"] >=0
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 533    False
# 534     True
# 535     True
# 536    False
# 537     True
# Name: Lat, Length: 538, dtype: bool

# %%
# inside def when we call need to give 5 arguments x_values, y_values, title for chart, y_label, text_coordinates where the equation shows
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.grid(True)
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    
    plt.show()

# %%
#FROM THE DF FILTER ALL LAT > 0 using .loc
cities_data_df_read_csv.loc[(cities_data_df_read_csv["Lat"] >=0)].head()
# Out:
#     city-id           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3         3       Yinchuan  38.4681  106.2731     48.67        25          42
# 4         4          Tiksi  71.6872  128.8694     14.43        95         100
# 5         5     Greenville  35.6127  -77.3663     73.42        63           1
# 12       12  Cockburn Town  21.4612  -71.1419     82.71        77          15
# 14       14         Torbay  47.6666  -52.7314     51.58        76          75
#
#     Wind Speed Country                 Date
# 3         3.22      CN  2021-10-21 15:38:35
# 4        12.75      RU  2021-10-21 15:38:36
# 5         8.05      US  2021-10-21 15:38:36
# 12       16.69      TC  2021-10-21 15:33:57
# 14       26.46      CA  2021-10-21 15:35:36

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = cities_data_df_read_csv.loc[(cities_data_df_read_csv["Lat"] >= 0)]
southern_hemi_df = cities_data_df_read_csv.loc[(cities_data_df_read_csv["Lat"] < 0)]

# %%
northern_hemi_df
# Out:
#      city-id                City      Lat       Lng  Max Temp  Humidity  \
# 3          3            Yinchuan  38.4681  106.2731     48.67        25
# 4          4               Tiksi  71.6872  128.8694     14.43        95
# 5          5          Greenville  35.6127  -77.3663     73.42        63
# 12        12       Cockburn Town  21.4612  -71.1419     82.71        77
# 14        14              Torbay  47.6666  -52.7314     51.58        76
# ..       ...                 ...      ...       ...       ...       ...
# 530      530  Nizhniy Baskunchak  48.2198   46.8311     49.71        30
# 531      531         Derzhavinsk  51.1000   66.3167     36.14        63
# 534      534     Aleksandrov Gay  50.1470   48.5704     48.74        40
# 535      535          Srikakulam  18.3000   83.9000     81.05        80
# 537      537                Bara  10.3744   10.7288     92.21        42
#
#      Cloudiness  Wind Speed Country                 Date
# ...

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemi \ Max Temp', 'Max Temp',(6,10))




# plt.xlim(0, 80)
#plt.ylim(40, 110)
#plt.grid(True)
# plt.show()

# %%
southern_hemi_df
# Out:
#      city-id                   City      Lat       Lng  Max Temp  Humidity  \
# 0          0                Eenhana -17.4667   16.3333     90.32        13
# 1          1         Saint-Philippe -21.3585   55.7679     74.79        77
# 2          2                   Chuy -33.6971  -53.4616     68.68        48
# 6          6                Hualmay -11.0964  -77.6139     68.41        71
# 7          7              Cape Town -33.9258   18.4232     68.11        68
# ..       ...                    ...      ...       ...       ...       ...
# 527      527  Conceicao Do Araguaia  -8.2578  -49.2647     90.14        49
# 528      528               Antalaha -14.9003   50.2788     72.23        85
# 532      532                 Pangoa -12.1167  -73.0000     89.33        42
# 533      533                 Lobito -12.3481   13.5456     77.16        77
# 536      536                 Tiarei -17.5333 -149.3333     75.22        80
#
#      Cloudiness  Wind Speed Country                 Date
# ...

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemi \Max Temp', 'Max Temp',(-55,90))

# %%
# Lat vs humidity
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemi \ Humidity', '%Humidity',(40,10))

# %%
#lat vs humidity
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemi \Humidity', '%Humidity',(-50,20))

# %%
#Skill drill 6.4.4 
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemi \ % Cloudiness', '%Cloudiness',(45,5))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemi \ % Cloudiness', '%Cloudiness',(-50,60))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemi \  Wind Speed', ' Wind Speed (mph)',(5,24))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemi\ Wind Speed', ' Wind Speed(mph)',(-50,25))
